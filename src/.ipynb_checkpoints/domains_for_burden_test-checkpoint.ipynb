# %% [markdown]
# <a href="https://colab.research.google.com/github/artemkosmin/Domain-based-burden-analysis-in-PD-genes/blob/main/domains_for_burden_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bioservices

import os
import sys
import requests          
import pandas as pd

from  bioservices import UniProt
from bioservices import *
from IPython.display import clear_output

service = UniProt()
db = BioDBNet()

clear_output()

# %%
uniq_gene = set()
try:
  with open('condidate.txt') as f:
    for gene in f:
      uniq_gene.add(gene.strip())
finally:
  f.close()

# %%
columnlist = "id"
protein_coding_genes = []
no_protein_coding_genes = set()
protein_id = []
for gene in uniq_gene:
  query = f'gene:{gene} organism:human'
  id = service.search(query, columns=columnlist)
  if id:
    n = id.split('\n')[1]
    protein_id.append(n)
    protein_coding_genes.append(gene)
  else:
    no_protein_coding_genes.add(gene)

# %%
ens_g = db.dbFind('Ensembl Gene ID', protein_id)['Ensembl Gene ID'].to_list()

# %%
ensg_id = []
for id in ens_g:
  prot_id = id.split('//')
  if len(prot_id) > 1:
    print(id)
    for each in prot_id:
      if each not in ens_g:
        ensg_id.append(each)
  else:
    ensg_id.append(id)
# Out:
# ENSG00000189157//ENSG00000272414
# ENSG00000263715//ENSG00000120088

# %%
cdsstart = []
cdsmend = []
def cds_transcript_data(enst, ensg_id):

  global cdsstart
  global cdsend

  url = f'https://rest.ensembl.org/overlap/id/{ensg_id}?feature=cds'

  r = requests.get(url, headers={ "Content-Type" : "application/json"})
 
  if not r.ok:
    r.raise_for_status()
    sys.exit()
  
  data = r.json()

  coord = []

  for entry in data:
    if entry['Parent'] == enst:
      coord.extend([entry['start'],entry['end']])
  if entry['strand'] == 1:
    start = min(coord)
    end = max(coord)
    cdsstart.append(start)
    cdsmend.append(end)
  else:
    start = max(coord)
    end = min(coord)
    cdsstart.append(start)
    cdsmend.append(end)
# ensg_id
# for enst, ensp in zip(transc, ens_p):
#   cds_transcript_data(enst, ensp)

# %%
transc = []
chromosome = []
strand = []
chromstart = []
chromend = []
def canonical_transcript_data(name, gene_id):

  global transc
  global chromosome
  global strand
  global chromstart
  global chromend

  url = f'https://rest.ensembl.org/overlap/id/{gene_id}?feature=gene'

  r = requests.get(url, headers={ "Content-Type" : "application/json"})
 
  if not r.ok:
    r.raise_for_status()
    sys.exit()
  
  data = r.json()

  for entry in data:
    if entry['biotype'] == 'protein_coding' and entry['gene_id'] == gene_id:
      canonical_transcript_id = entry['canonical_transcript'].split('.')[0]
      st = '-' if entry['strand'] == -1 else '+'
      chrom = int(entry['seq_region_name'])
      chromStart = str(entry['start'])
      chromEnd = str(entry['end'])
      transc.append(canonical_transcript_id)
      chromosome.append(chrom)
      strand.append(st)
      chromstart.append(chromStart)
      chromend.append(chromEnd)
      #print(', '.join([name, canonical_transcript_id, strand, chrom, chromStart, chromEnd]))

# %%
for name, id in zip(protein_coding_genes, ensg_id):
  canonical_transcript_data(name, id)

# %%
for enst, ensp in zip(transc, ensg_id):
  cds_transcript_data(enst, ensp)

# %%
ens_p = db.dbFind('Ensembl Protein ID', transc)['Ensembl Protein ID'].to_list()

# %%
time_df = pd.DataFrame({'name': protein_coding_genes,
                        'chromosome': chromosome,
                        'strand': strand,
                        'chromStart': chromstart,
                        'chromEnd': chromend,
                        'cdsStart': cdsstart,
                        'cdsEnd': cdsmend, 
                        'protein_id': protein_id, 
                        'ensg_id': ensg_id,
                        'enst_id': transc,
                        'ensp_id': ens_p})

# %%
time_df = time_df.sort_values(['chromosome'], ignore_index=True)

# %%
def domain_coordinates(url, name, enst, ensp, chr, st, chS, chE, cdsS, cdsE):
  global result_df 
  domain = []
  for part in url.json()['results']:
    part_type = part['metadata']['type']
    source = None if not part['metadata']['member_databases'] else list(part['metadata']['member_databases'].keys())
    fragments = part['proteins'][0]['entry_protein_locations']
    if len(fragments) != 1:
      domain_name = name + '__' + part['metadata']['name']
      start = []
      end = []
      for fragment in fragments:
        start.append(fragment['fragments'][0]['start'])
        end.append(fragment['fragments'][0]['end'])
      domain.append((name, domain_name, enst, ensp, start, end, part_type, source, chr, st, chS, chE, cdsS, cdsE))
    else:
      domain_name = name + '__' + part['metadata']['name']
      start = fragments[0]['fragments'][0]['start']
      end = fragments[0]['fragments'][0]['end']
      domain.append((name, domain_name, enst, ensp, [start], [end], part_type, source, chr, st, chS, chE, cdsS, cdsE))
  sorted_domain = sorted(domain, key=lambda x: int(x[4][0]))
  df = pd.DataFrame(sorted_domain, columns = ['gene_name', 'domain', 'enst_id', 
                                              'ensp_id', 'start', 'end', 
                                              'part_type', 'source', 'chromosome', 
                                              'strand', 'chromStart', 'chromEnd', 
                                              'cdsStart', 'cdsEnd'])
  result_df = pd.concat([result_df, df])

# %%
def make_request(status, protein_id):
  return requests.get(f'https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/{status}/{protein_id}/')

# %%
def status_check(name, enst, ensp, protein_id, chr, st, chS, chE, cdsS, cdsE):
  status = ['reviewed', 'unreviewed']
  url = make_request(status[0], protein_id)
  if url.status_code != 204:
    domain_coordinates(url, name, enst, ensp, chr, st, chS, chE, cdsS, cdsE)
  else:
    url = make_request(status[1], protein_id)
    domain_coordinates(url, name, enst, ensp, chr, st, chS, chE, cdsS, cdsE)

# %%
result_df = pd.DataFrame(columns = ['gene_name', 
                                    'domain', 
                                    'enst_id', 
                                    'ensp_id', 
                                    'start', 
                                    'end', 
                                    'part_type', 
                                    'source', 
                                    'chromosome', 
                                    'strand', 
                                    'chromStart', 
                                    'chromEnd', 
                                    'cdsStart',
                                    'cdsEnd'])
time_df.apply(
    lambda row: status_check(row['name'], row['enst_id'], row['ensp_id'], row['protein_id'], row['chromosome'], row['strand'], row['chromStart'], row['chromEnd'], row['cdsStart'], row['cdsEnd']),
    axis = 1
)
clear_output()

# %%
def to_str(x):
  return ', '.join(str(i) for i in x)

for i in ['start', 'end', 'source']:
  love = result_df.apply(
      lambda row: to_str(row[i]),
      axis = 1
  )
  result_df[i] = love

# %%
result_df.to_csv('first_table.txt', sep = '\t', index=None)

# %%
interval_start = []
interval_end = []

def mapping_to_chromosome(protein_id, start, end):

  start = start.split(',')
  end = end.split(',')

  d_s = []
  d_e = []

  global interval_start
  global interval_end

  for s, e in zip(start, end):
    url = f"https://rest.ensembl.org/map/translation/{protein_id}/{s}..{e}?"
  
    r = requests.get(url, headers={ "Content-Type" : "application/json"})
  
    if not r.ok:
      r.raise_for_status()
      sys.exit()
    
    for interval in r.json()['mappings']:
      d_s.append(interval['start'])
      d_e.append(interval['end'])

  interval_start.append(d_s)
  interval_end.append(d_e)

# %%
result_df.apply(
    lambda row: mapping_to_chromosome(row['ensp_id'], row['start'], row['end']),
    axis = 1
)
result_df['domain_start'] = interval_start
result_df['domain_end'] = interval_end

# %%
def count_domain_intervals(s, e):
  count = int(len(s))
  if len(s) == len(e):
    return count

# %%
def chromosoma(x):
  return 'chr' + str(x)

# %%
love = result_df.apply(
    lambda row: chromosoma(row['chromosome']),
    axis = 1 
)
result_df['chrom'] = love

# %%
love = result_df.apply(
    lambda row: count_domain_intervals(row['domain_start'], row['domain_end']),
    axis = 1 
)
result_df['domain_count'] = love

# %%
new_df = result_df[['domain', 'enst_id', 'chrom', 
               'strand', 'chromStart', 'chromEnd', 
               'cdsStart', 'cdsEnd', 'domain_count', 
               'domain_start', 'domain_end', 'part_type', 'source']]
new_df
# Out:
#                                                domain          enst_id  chrom  \
# 0                    FCGR2A__Immunoglobulin-like fold  ENST00000271450   chr1
# 1      FCGR2A__Immunoglobulin-like domain superfamily  ENST00000271450   chr1
# 2                  FCGR2A__Immunoglobulin-like domain  ENST00000271450   chr1
# 3                      FCGR2A__Immunoglobulin subtype  ENST00000271450   chr1
# 4                    FCGR2A__Immunoglobulin subtype 2  ENST00000271450   chr1
# ..                                                ...              ...    ...
# 1      DYRK1A__Protein kinase-like domain superfamily  ENST00000647188  chr21
# 2   DYRK1A__Dual specificity tyrosine-phosphorylat...  ENST00000647188  chr21
# 3                       DYRK1A__Protein kinase domain  ENST00000647188  chr21
# 4            DYRK1A__Protein kinase, ATP binding site  ENST00000647188  chr21
# 5   DYRK1A__Serine/threonine-protein kinase, activ...  ENST00000647188  chr21
#
#    strand chromStart   chromEnd   cdsStart     cdsEnd  domain_count  \
# 0       +  161505430  161524013  161505468  161518148             3
# 1       +  161505430  161524013  161505468  161518148             3
# 2       +  161505430  161524013  161505468  161518148             3
# 3       +  161505430  161524013  161505468  161518148             2
# 4       +  161505430  161524013  161505468  161518148             2
# ..    ...        ...        ...        ...        ...           ...
# 1       +   37365573   37526358   37420375   37512531             6
# 2       +   37365573   37526358   37420375   37512531             6
# 3       +   37365573   37526358   37420375   37512531             6
# 4       +   37365573   37526358   37420375   37512531             1
# 5       +   37365573   37526358   37420375   37512531             1
#
#                                          domain_start  \
# 0                   [161506336, 161509822, 161510834]
# 1                   [161506339, 161506585, 161509820]
# 2                   [161506342, 161506591, 161509820]
# 3                              [161506366, 161509837]
# 4                              [161506384, 161509855]
# ..                                                ...
# 1   [37480776, 37486467, 37490175, 37493017, 37496...
# 2   [37480779, 37486467, 37490175, 37493017, 37496...
# 3   [37480812, 37486467, 37490175, 37493017, 37496...
# 4                                          [37486470]
# 5                                          [37490384]
#
#                                            domain_end               part_type  \
# 0                   [161506590, 161510074, 161510835]  homologous_superfamily
# 1                   [161506584, 161506591, 161510070]  homologous_superfamily
# 2                   [161506584, 161506591, 161510070]                  domain
# 3                              [161506587, 161510073]                  domain
# 4                              [161506560, 161510037]                  domain
# ..                                                ...                     ...
# 1   [37480826, 37486614, 37490461, 37493163, 37496...  homologous_superfamily
# 2   [37480826, 37486614, 37490461, 37493163, 37496...                  domain
# 3   [37480826, 37486614, 37490461, 37493163, 37496...                  domain
# 4                                          [37486541]            binding_site
# 5                                          [37490422]             active_site
#
#                 source
# 0           cathgene3d
# 1                  ssf
# 2         pfam,profile
# 3                smart
# 4                smart
# ..                 ...
# 1                  ssf
# 2                  cdd
# 3   profile,pfam,smart
# 4              prosite
# 5              prosite
#
# [508 rows x 13 columns]

# %%
for i in ['domain_start', 'domain_end']:
  love = new_df.apply(
      lambda row: to_str(row[i]),
      axis = 1
  )
  new_df[i] = love
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_df
# Out:
#                                                domain          enst_id  chrom  \
# 0                    FCGR2A__Immunoglobulin-like fold  ENST00000271450   chr1
# 1      FCGR2A__Immunoglobulin-like domain superfamily  ENST00000271450   chr1
# 2                  FCGR2A__Immunoglobulin-like domain  ENST00000271450   chr1
# 3                      FCGR2A__Immunoglobulin subtype  ENST00000271450   chr1
# 4                    FCGR2A__Immunoglobulin subtype 2  ENST00000271450   chr1
# ..                                                ...              ...    ...
# 1      DYRK1A__Protein kinase-like domain superfamily  ENST00000647188  chr21
# 2   DYRK1A__Dual specificity tyrosine-phosphorylat...  ENST00000647188  chr21
# 3                       DYRK1A__Protein kinase domain  ENST00000647188  chr21
# 4            DYRK1A__Protein kinase, ATP binding site  ENST00000647188  chr21
# 5   DYRK1A__Serine/threonine-protein kinase, activ...  ENST00000647188  chr21
#
#    strand chromStart   chromEnd   cdsStart     cdsEnd  domain_count  \
# 0       +  161505430  161524013  161505468  161518148             3
# 1       +  161505430  161524013  161505468  161518148             3
# 2       +  161505430  161524013  161505468  161518148             3
# 3       +  161505430  161524013  161505468  161518148             2
# 4       +  161505430  161524013  161505468  161518148             2
# ..    ...        ...        ...        ...        ...           ...
# 1       +   37365573   37526358   37420375   37512531             6
# 2       +   37365573   37526358   37420375   37512531             6
# 3       +   37365573   37526358   37420375   37512531             6
# 4       +   37365573   37526358   37420375   37512531             1
# 5       +   37365573   37526358   37420375   37512531             1
#
#                                          domain_start  \
# 0                       161506336,161509822,161510834
# 1                       161506339,161506585,161509820
# 2                       161506342,161506591,161509820
# 3                                 161506366,161509837
# 4                                 161506384,161509855
# ..                                                ...
# 1   37480776,37486467,37490175,37493017,37496118,3...
# 2   37480779,37486467,37490175,37493017,37496118,3...
# 3   37480812,37486467,37490175,37493017,37496118,3...
# 4                                            37486470
# 5                                            37490384
#
#                                            domain_end               part_type  \
# 0                       161506590,161510074,161510835  homologous_superfamily
# 1                       161506584,161506591,161510070  homologous_superfamily
# 2                       161506584,161506591,161510070                  domain
# 3                                 161506587,161510073                  domain
# 4                                 161506560,161510037                  domain
# ..                                                ...                     ...
# 1   37480826,37486614,37490461,37493163,37496258,3...  homologous_superfamily
# 2   37480826,37486614,37490461,37493163,37496258,3...                  domain
# 3   37480826,37486614,37490461,37493163,37496258,3...                  domain
# 4                                            37486541            binding_site
# 5                                            37490422             active_site
#
#                 source
# 0           cathgene3d
# 1                  ssf
# 2         pfam,profile
# 3                smart
# 4                smart
# ..                 ...
# 1                  ssf
# 2                  cdd
# 3   profile,pfam,smart
# 4              prosite
# 5              prosite
#
# [508 rows x 13 columns]

# %% [markdown]
# To perfrom protein coordinates to genome, we can use ensembldb package for R.

# %%
# !Rscript chromosome_coordinates.R
# Out:
# Streaming output truncated to the last 5000 lines.
# 65 183092409, 183086693, 183072366, 183071210, 183070999, 183057311, 183052159, 183045413, 183041567, 183039026, 183037330
#                                                                                                                    end_chr
# 65 183092540, 183086788, 183072487, 183071357, 183071120, 183057422, 183052240, 183045540, 183041750, 183039135, 183037434
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                            domain         enst_id
# 66     MCCC1 MCCC1__Biotin carboxylase-like, N-terminal domain ENST00000265594
#            ensp_id start end part_type source chromosome strand chromStart
# 66 ENSP00000265594    49 157    domain   pfam          3      -  183015218
#     chromEnd  cdsStart    cdsEnd                       start_chr
# 66 183116075 183099440 183015438 183092409, 183086693, 183072386
#                            end_chr
# 66 183092537, 183086788, 183072487
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name
# 67     MCCC1
#                                                                          domain
# 67 MCCC1__Carbamoyl-phosphate synthetase large subunit-like, ATP-binding domain
#            enst_id         ensp_id start end part_type       source chromosome
# 67 ENST00000265594 ENSP00000265594   163 369    domain prosite,pfam          3
#    strand chromStart  chromEnd  cdsStart    cdsEnd
# 67      -  183015218 183116075 183099440 183015438
#                                                                      start_chr
# 67 183072366, 183071210, 183070999, 183057311, 183052159, 183045413, 183041727
#                                                                        end_chr
# 67 183072370, 183071357, 183071120, 183057422, 183052240, 183045540, 183041750
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                domain         enst_id         ensp_id start end
# 68     MCCC1 MCCC1__ATP-grasp fold ENST00000265594 ENSP00000265594   167 364
#    part_type  source chromosome strand chromStart  chromEnd  cdsStart    cdsEnd
# 68    domain profile          3      -  183015218 183116075 183099440 183015438
#                                                           start_chr
# 68 183071210, 183070999, 183057311, 183052159, 183045413, 183041742
#                                                             end_chr
# 68 183071350, 183071120, 183057422, 183052240, 183045540, 183041750
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                              domain         enst_id
# 69     MCCC1 MCCC1__Rudiment single hybrid motif ENST00000265594
#            ensp_id start end              part_type source chromosome strand
# 69 ENSP00000265594   378 496 homologous_superfamily    ssf          3      -
#    chromStart  chromEnd  cdsStart    cdsEnd                       start_chr
# 69  183015218 183116075 183099440 183015438 183041567, 183039026, 183037324
#                            end_chr
# 69 183041702, 183039135, 183037434
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                domain         enst_id
# 70     MCCC1 MCCC1__Biotin carboxylase, C-terminal ENST00000265594
#            ensp_id start end part_type     source chromosome strand chromStart
# 70 ENSP00000265594   383 490    domain smart,pfam          3      -  183015218
#     chromEnd  cdsStart    cdsEnd                       start_chr
# 70 183116075 183099440 183015438 183041567, 183039026, 183037342
#                            end_chr
# 70 183041687, 183039135, 183037434
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                     domain         enst_id         ensp_id start
# 71     MCCC1 MCCC1__Single hybrid motif ENST00000265594 ENSP00000265594   642
#    end              part_type source chromosome strand chromStart  chromEnd
# 71 715 homologous_superfamily    ssf          3      -  183015218 183116075
#     cdsStart    cdsEnd                       start_chr
# 71 183099440 183015438 183020130, 183017266, 183015471
#                            end_chr
# 71 183020183, 183017337, 183015566
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                          domain         enst_id         ensp_id
# 72     MCCC1 MCCC1__Biotin/lipoyl attachment ENST00000265594 ENSP00000265594
#    start end part_type       source chromosome strand chromStart  chromEnd
# 72   643 715    domain profile,pfam          3      -  183015218 183116075
#     cdsStart    cdsEnd                       start_chr
# 72 183099440 183015438 183020130, 183017266, 183015471
#                            end_chr
# 72 183020180, 183017337, 183015566
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                     domain         enst_id         ensp_id start
# 73     MCCC1 MCCC1__Biotin-binding site ENST00000265594 ENSP00000265594   671
#    end    part_type  source chromosome strand chromStart  chromEnd  cdsStart
# 73 688 binding_site prosite          3      -  183015218 183116075 183099440
#       cdsEnd            start_chr              end_chr
# 73 183015438 183017266, 183015552 183017304, 183015566
# Fetching CDS for 1 proteins ... 0 found
# Checking CDS and protein sequence lengths ... 0/1 OK
#    gene_name                                  domain         enst_id
# 74    MED12L MED12L__Mediator complex, subunit Med12 ENST00000687756
#            ensp_id start end part_type     source chromosome strand chromStart
# 74 ENSP00000508695   101 161    domain smart,pfam          3      +  151085286
#     chromEnd  cdsStart    cdsEnd start_chr end_chr
# 74 151437072 151086927 151432804                NA
# Fetching CDS for 1 proteins ... 0 found
# Checking CDS and protein sequence lengths ... 0/1 OK
#    gene_name                                                 domain
# 75    MED12L MED12L__Mediator complex, subunit Med12, LCEWAV-domain
#            enst_id         ensp_id start end part_type source chromosome strand
# 75 ENST00000687756 ENSP00000508695   283 730    domain   pfam          3      +
#    chromStart  chromEnd  cdsStart    cdsEnd start_chr end_chr
# 75  151085286 151437072 151086927 151432804                NA
# Fetching CDS for 1 proteins ... 0 found
# Checking CDS and protein sequence lengths ... 0/1 OK
#    gene_name                                                   domain
# 76    MED12L MED12L__Mediator complex, subunit Med12, catenin-binding
#            enst_id         ensp_id start  end part_type source chromosome
# 76 ENST00000687756 ENSP00000508695  1802 2019    domain   pfam          3
#    strand chromStart  chromEnd  cdsStart    cdsEnd start_chr end_chr
# 76      +  151085286 151437072 151086927 151432804                NA
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                               domain         enst_id
# 77     IP6K2 IP6K2__Inositol polyphosphate kinase ENST00000328631
#            ensp_id start end part_type       source chromosome strand
# 77 ENSP00000331103     1 426    family panther,pfam          3      -
#    chromStart chromEnd cdsStart   cdsEnd
# 77   48688003 48740353 48695291 48688273
#                                           start_chr
# 77 48695090, 48692954, 48691307, 48689538, 48688276
#                                             end_chr
# 77 48695291, 48693179, 48691482, 48689713, 48688773
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                           domain         enst_id
# 78     IP6K2 IP6K2__Inositol polyphosphate kinase superfamily ENST00000328631
#            ensp_id start end              part_type     source chromosome
# 78 ENSP00000331103   146 425 homologous_superfamily cathgene3d          3
#    strand chromStart chromEnd cdsStart   cdsEnd                    start_chr
# 78      -   48688003 48740353 48695291 48688273 48691307, 48689538, 48688279
#                         end_chr
# 78 48691475, 48689713, 48688773
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                 domain         enst_id
# 79     SATB1 SATB1__DNA-binding protein SATB1/SATB2 ENST00000338745
#            ensp_id start end part_type  source chromosome strand chromStart
# 79 ENSP00000341024     1 763    family panther          3      -   18345377
#    chromEnd cdsStart   cdsEnd
# 79 18445588 18420967 18349170
#                                                                                             start_chr
# 79 18420757, 18416902, 18416007, 18415111, 18397179, 18394462, 18386399, 18378170, 18351992, 18349173
#                                                                                               end_chr
# 79 18420967, 18417078, 18416133, 18415234, 18397290, 18394916, 18386611, 18378325, 18352195, 18349682
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                              domain         enst_id
# 80     SATB1 SATB1__SATB, ULD domain superfamily ENST00000338745
#            ensp_id start end              part_type     source chromosome
# 80 ENSP00000341024    68 169 homologous_superfamily cathgene3d          3
#    strand chromStart chromEnd cdsStart   cdsEnd                    start_chr
# 80      -   18345377 18445588 18420967 18349170 18420757, 18416902, 18416015
#                         end_chr
# 80 18420766, 18417078, 18416133
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                             domain         enst_id
# 81     SATB1 SATB1__SATB, ubiquitin-like oligomerisation domain ENST00000338745
#            ensp_id start end part_type   source chromosome strand chromStart
# 81 ENSP00000341024    73 170    domain cdd,pfam          3      -   18345377
#    chromEnd cdsStart   cdsEnd          start_chr            end_chr
# 81 18445588 18420967 18349170 18416902, 18416012 18417073, 18416133
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                               domain         enst_id
# 82     SATB1 SATB1__SATB, CUTL domain superfamily ENST00000338745
#            ensp_id start end              part_type     source chromosome
# 82 ENSP00000341024   170 250 homologous_superfamily cathgene3d          3
#    strand chromStart chromEnd cdsStart   cdsEnd                    start_chr
# 82      -   18345377 18445588 18420967 18349170 18416007, 18415111, 18397180
#                         end_chr
# 82 18416014, 18415234, 18397290
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                    domain         enst_id
# 83     SATB1 SATB1__SATB, CUT1-like DNA-binding domain ENST00000338745
#            ensp_id start end part_type source chromosome strand chromStart
# 83 ENSP00000341024   177 247    domain   pfam          3      -   18345377
#    chromEnd cdsStart   cdsEnd          start_chr            end_chr
# 83 18445588 18420967 18349170 18415111, 18397189 18415221, 18397290
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name            domain         enst_id         ensp_id   start     end
# 84     SATB1 SATB1__CUT domain ENST00000338745 ENSP00000341024 361,484 448,571
#    part_type             source chromosome strand chromStart chromEnd cdsStart
# 84    domain smart,profile,pfam          3      -   18345377 18445588 18420967
#      cdsEnd                              start_chr
# 84 18349170 18394462, 18386474, 18378170, 18352058
#                                   end_chr
# 84 18394587, 18386611, 18378295, 18352195
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                                       domain
# 85     SATB1 SATB1__Lambda repressor-like, DNA-binding domain superfamily
#            enst_id         ensp_id   start     end              part_type
# 85 ENST00000338745 ENSP00000341024 366,479 450,576 homologous_superfamily
#            source chromosome strand chromStart chromEnd cdsStart   cdsEnd
# 85 ssf,cathgene3d          3      -   18345377 18445588 18420967 18349170
#                                 start_chr
# 85 18394462, 18386468, 18378170, 18352043
#                                   end_chr
# 85 18394572, 18386611, 18378310, 18352195
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                  domain         enst_id
# 86     SATB1 SATB1__Homeobox-like domain superfamily ENST00000338745
#            ensp_id start end              part_type source chromosome strand
# 86 ENSP00000341024   639 703 homologous_superfamily    ssf          3      -
#    chromStart chromEnd cdsStart   cdsEnd start_chr  end_chr
# 86   18345377 18445588 18420967 18349170  18349353 18349547
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                 domain         enst_id         ensp_id start end
# 87     SATB1 SATB1__Homeobox domain ENST00000338745 ENSP00000341024   642 707
#    part_type                 source chromosome strand chromStart chromEnd
# 87    domain cdd,profile,smart,pfam          3      -   18345377 18445588
#    cdsStart   cdsEnd start_chr  end_chr
# 87 18420967 18349170  18349341 18349538
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#       gene_name                     domain         enst_id         ensp_id
# 88 FAM47E-STBD1 FAM47E-STBD1__FAM47 family ENST00000515604 ENSP00000422067
#    start end part_type       source chromosome strand chromStart chromEnd
# 88     1 132    family panther,pfam          4      +   76251721 76311129
#    cdsStart   cdsEnd          start_chr            end_chr
# 88 76251747 76309173 76251747, 76256178 76251820, 76256499
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                                 domain
# 89   TMEM175 TMEM175__Endosomal/lysomomal potassium channel TMEM175
#            enst_id         ensp_id  start     end part_type source chromosome
# 89 ENST00000264771 ENSP00000264771 35,260 124,356    family   pfam          4
#    strand chromStart chromEnd cdsStart cdsEnd
# 89      +     932387   958656   947740 958496
#                                                 start_chr
# 89 947842, 948116, 950421, 951207, 951682, 955826, 957824
#                                                   end_chr
# 89 947892, 948154, 950518, 951258, 951711, 955890, 958049
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                      domain         enst_id
# 90       GAK GAK__Protein kinase-like domain superfamily ENST00000314167
#            ensp_id start end              part_type source chromosome strand
# 90 ENSP00000314499    39 322 homologous_superfamily    ssf          4      -
#    chromStart chromEnd cdsStart cdsEnd
# 90     849276   932373   932187 849673
#                                                                 start_chr
# 90 932043, 913607, 912735, 911673, 904637, 898033, 896460, 893874, 893401
#                                                                   end_chr
# 90 932073, 913668, 912794, 911787, 904779, 898158, 896549, 894009, 893489
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                     domain         enst_id         ensp_id start
# 91       GAK GAK__Protein kinase domain ENST00000314167 ENSP00000314499    40
#    end part_type             source chromosome strand chromStart chromEnd
# 91 317    domain profile,pfam,smart          4      -     849276   932373
#    cdsStart cdsEnd
# 91   932187 849673
#                                                                 start_chr
# 91 932043, 913607, 912735, 911673, 904637, 898033, 896460, 893874, 893416
#                                                                   end_chr
# 91 932070, 913668, 912794, 911787, 904779, 898158, 896549, 894009, 893489
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                            domain         enst_id
# 92       GAK GAK__Serine/threonine-protein kinase, active site ENST00000314167
#            ensp_id start end   part_type  source chromosome strand chromStart
# 92 ENSP00000314499   169 181 active_site prosite          4      -     849276
#    chromEnd cdsStart cdsEnd      start_chr        end_chr
# 92   932373   932187 849673 904637, 898141 904657, 898158
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                              domain         enst_id
# 93       GAK GAK__Tensin-type phosphatase domain ENST00000314167
#            ensp_id start end part_type  source chromosome strand chromStart
# 93 ENSP00000314499   399 566    domain profile          4      -     849276
#    chromEnd cdsStart cdsEnd                                      start_chr
# 93   932373   932187 849673 888847, 884037, 883315, 882697, 881907, 877773
#                                           end_chr
# 93 888857, 884086, 883463, 882819, 882040, 877809
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                 domain         enst_id
# 94       GAK GAK__Protein-tyrosine phosphatase-like ENST00000314167
#            ensp_id start end              part_type         source chromosome
# 94 ENSP00000314499   407 566 homologous_superfamily ssf,cathgene3d          4
#    strand chromStart chromEnd cdsStart cdsEnd
# 94      -     849276   932373   932187 849673
#                                 start_chr
# 94 884037, 883315, 882697, 881907, 877773
#                                   end_chr
# 94 884073, 883463, 882819, 882040, 877809
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                             domain         enst_id         ensp_id
# 95       GAK GAK__Tensin phosphatase, C2 domain ENST00000314167 ENSP00000314499
#    start end part_type             source chromosome strand chromStart chromEnd
# 95   570 710    domain smart,profile,pfam          4      -     849276   932373
#    cdsStart cdsEnd                      start_chr
# 95   932187 849673 877615, 877090, 876530, 870829
#                           end_chr
# 95 877763, 877207, 876609, 870904
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                     domain         enst_id         ensp_id start
# 96       GAK GAK__C2 domain superfamily ENST00000314167 ENSP00000314499   571
#    end              part_type         source chromosome strand chromStart
# 96 708 homologous_superfamily ssf,cathgene3d          4      -     849276
#    chromEnd cdsStart cdsEnd                      start_chr
# 96   932373   932187 849673 877615, 877090, 876530, 870835
#                           end_chr
# 96 877760, 877207, 876609, 870904
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                              domain         enst_id
# 97       GAK GAK__Chaperone J-domain superfamily ENST00000314167
#            ensp_id start  end              part_type         source chromosome
# 97 ENSP00000314499  1153 1310 homologous_superfamily cathgene3d,ssf          4
#    strand chromStart chromEnd cdsStart cdsEnd                      start_chr
# 97      -     849276   932373   932187 849673 851750, 850936, 849892, 849679
#                           end_chr
# 97 851801, 851084, 850068, 849774
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name           domain         enst_id         ensp_id start  end
# 98       GAK GAK__DnaJ domain ENST00000314167 ENSP00000314499  1246 1311
#    part_type                        source chromosome strand chromStart
# 98    domain profile,prints,cdd,pfam,smart          4      -     849276
#    chromEnd cdsStart cdsEnd      start_chr        end_chr
# 98   932373   932187 849673 849892, 849676 849990, 849774
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#    gene_name                                  domain         enst_id
# 99     LCORL LCORL__Homeobox-like domain superfamily ENST00000635767
#            ensp_id   start     end              part_type source chromosome
# 99 ENSP00000490600 272,520 324,577 homologous_superfamily    ssf          4
#    strand chromStart chromEnd cdsStart   cdsEnd          start_chr
# 99      -   17841187 18021876 18021751 17845888 17878018, 17877259
#               end_chr
# 99 17878176, 17877432
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                  domain         enst_id
# 100     LCORL LCORL__DNA binding HTH domain, Psq-type ENST00000635767
#             ensp_id   start     end part_type       source chromosome strand
# 100 ENSP00000490600 280,516 309,570    domain profile,pfam          4      -
#     chromStart chromEnd cdsStart   cdsEnd          start_chr            end_chr
# 100   17841187 18021876 18021751 17845888 17878063, 17877280 17878152, 17877444
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                               domain         enst_id
# 101    SCARB2 SCARB2__Lysosome membrane protein II ENST00000264896
#             ensp_id                            start
# 101 ENSP00000264896 3,29,127,151,182,257,298,386,454
#                                   end part_type source chromosome strand
# 101 27,52,145,171,199,273,318,407,477    family prints          4      -
#     chromStart chromEnd cdsStart   cdsEnd
# 101   76158737 76234536 76213543 76161713
#                                                                                                                            start_chr
# 101 76213463, 76213427, 76195826, 76180954, 76179694, 76179616, 76179532, 76175796, 76174184, 76168403, 76166268, 76163225, 76161719
#                                                                                                                              end_chr
# 101 76213537, 76213459, 76195864, 76180998, 76179705, 76179678, 76179585, 76175846, 76174246, 76168434, 76166301, 76163263, 76161751
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name              domain         enst_id         ensp_id start end
# 102    SCARB2 SCARB2__CD36 family ENST00000264896 ENSP00000264896    11 478
#     part_type              source chromosome strand chromStart chromEnd
# 102    family panther,pfam,prints          4      -   76158737 76234536
#     cdsStart   cdsEnd
# 102 76213543 76161713
#                                                                                                                  start_chr
# 102 76213427, 76195707, 76180954, 76179517, 76176437, 76175791, 76174144, 76169867, 76168403, 76166250, 76163225, 76161716
#                                                                                                                    end_chr
# 102 76213513, 76195864, 76181101, 76179705, 76176528, 76175910, 76174313, 76169985, 76168476, 76166301, 76163383, 76161751
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                         domain         enst_id
# 103    CAMK2D CAMK2D__Protein kinase-like domain superfamily ENST00000511664
#             ensp_id start end              part_type source chromosome strand
# 103 ENSP00000425824    10 273 homologous_superfamily    ssf          4      -
#     chromStart  chromEnd  cdsStart    cdsEnd
# 103  113418054 113761927 113761068 113455755
#                                                                                                        start_chr
# 103 113761004, 113759320, 113661713, 113609152, 113552031, 113547644, 113537341, 113531216, 113517563, 113515069
#                                                                                                          end_chr
# 103 113761041, 113759414, 113661772, 113609206, 113552096, 113547716, 113537443, 113531299, 113517657, 113515191
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                        domain         enst_id         ensp_id
# 104    CAMK2D CAMK2D__Protein kinase domain ENST00000511664 ENSP00000425824
#     start end part_type             source chromosome strand chromStart
# 104    14 272    domain profile,pfam,smart          4      -  113418054
#      chromEnd  cdsStart    cdsEnd
# 104 113761927 113761068 113455755
#                                                                                                        start_chr
# 104 113761004, 113759320, 113661713, 113609152, 113552031, 113547644, 113537341, 113531216, 113517563, 113515072
#                                                                                                          end_chr
# 104 113761029, 113759414, 113661772, 113609206, 113552096, 113547716, 113537443, 113531299, 113517657, 113515191
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                   domain         enst_id
# 105    CAMK2D CAMK2D__Protein kinase, ATP binding site ENST00000511664
#             ensp_id start end    part_type  source chromosome strand chromStart
# 105 ENSP00000425824    20  43 binding_site prosite          4      -  113418054
#      chromEnd  cdsStart    cdsEnd            start_chr              end_chr
# 105 113761927 113761068 113455755 113761004, 113759351 113761011, 113759414
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                               domain
# 106    CAMK2D CAMK2D__Serine/threonine-protein kinase, active site
#             enst_id         ensp_id start end   part_type  source chromosome
# 106 ENST00000511664 ENSP00000425824   132 144 active_site prosite          4
#     strand chromStart  chromEnd  cdsStart    cdsEnd            start_chr
# 106      -  113418054 113761927 113761068 113455755 113547644, 113537426
#                  end_chr
# 106 113547664, 113537443
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                               domain         enst_id
# 107    CAMK2D CAMK2D__NTF2-like domain superfamily ENST00000511664
#             ensp_id start end              part_type source chromosome strand
# 107 ENSP00000425824   340 470 homologous_superfamily    ssf          4      -
#     chromStart  chromEnd  cdsStart    cdsEnd
# 107  113418054 113761927 113761068 113455755
#                                                            start_chr
# 107 113504976, 113502936, 113500463, 113465529, 113460147, 113457460
#                                                              end_chr
# 107 113505002, 113502977, 113500511, 113465604, 113460241, 113457563
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name
# 108    CAMK2D
#                                                                         domain
# 108 CAMK2D__Calcium/calmodulin-dependent protein kinase II, association-domain
#             enst_id         ensp_id start end part_type source chromosome
# 108 ENST00000511664 ENSP00000425824   346 473    domain   pfam          4
#     strand chromStart  chromEnd  cdsStart    cdsEnd
# 108      -  113418054 113761927 113761068 113455755
#                                                            start_chr
# 108 113504976, 113502936, 113500463, 113465529, 113460147, 113457451
#                                                              end_chr
# 108 113504984, 113502977, 113500511, 113465604, 113460241, 113457563
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                        domain         enst_id         ensp_id
# 109     CLCN3 CLCN3__Chloride channel ClC-3 ENST00000513761 ENSP00000424603
#                 start                end part_type source chromosome strand
# 109 59,97,114,198,474 69,103,120,208,483    family prints          4      +
#     chromStart  chromEnd  cdsStart    cdsEnd
# 109  169612633 169723673 169635929 169719997
#                                                            start_chr
# 109 169680064, 169680178, 169687679, 169689216, 169690530, 169697591
#                                                              end_chr
# 109 169680096, 169680198, 169687699, 169689230, 169690547, 169697620
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                        domain         enst_id         ensp_id
# 110     CLCN3 CLCN3__Chloride channel, core ENST00000513761 ENSP00000424603
#     start end              part_type source chromosome strand chromStart
# 110   115 645 homologous_superfamily    ssf          4      +  169612633
#      chromEnd  cdsStart    cdsEnd
# 110 169723673 169635929 169719997
#                                                                                  start_chr
# 110 169687682, 169689043, 169690530, 169692114, 169695612, 169697189, 169703998, 169706868
#                                                                                    end_chr
# 110 169687757, 169689230, 169690652, 169692320, 169695692, 169697734, 169704184, 169707052
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                 domain         enst_id
# 111     CLCN3 CLCN3__Chloride channel, voltage gated ENST00000513761
#             ensp_id   start     end part_type      source chromosome strand
# 111 ENSP00000424603 221,629 621,643    family pfam,prints          4      +
#     chromStart  chromEnd  cdsStart    cdsEnd
# 111  169612633 169723673 169635929 169719997
#                                                                       start_chr
# 111 169690584, 169692114, 169695612, 169697189, 169703998, 169706868, 169707002
#                                                                         end_chr
# 111 169690652, 169692320, 169695692, 169697734, 169704184, 169706980, 169707046
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                        domain         enst_id         ensp_id
# 112     CLCN3 CLCN3__CBS domain superfamily ENST00000513761 ENSP00000424603
#     start end              part_type         source chromosome strand
# 112   652 810 homologous_superfamily cathgene3d,ssf          4      +
#     chromStart  chromEnd  cdsStart    cdsEnd                       start_chr
# 112  169612633 169723673 169635929 169719997 169707071, 169713079, 169719907
#                             end_chr
# 112 169707266, 169713295, 169719970
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name            domain         enst_id         ensp_id   start     end
# 113     CLCN3 CLCN3__CBS domain ENST00000513761 ENSP00000424603 656,755 722,812
#     part_type             source chromosome strand chromStart  chromEnd
# 113    domain profile,pfam,smart          4      +  169612633 169723673
#      cdsStart    cdsEnd                                  start_chr
# 113 169635929 169719997 169707083, 169713079, 169713192, 169719907
#                                        end_chr
# 113 169707266, 169713095, 169713295, 169719976
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                               domain         enst_id
# 114      BST1 BST1__ADP-ribosyl cyclase (CD38/157) ENST00000265016
#             ensp_id start end part_type           source chromosome strand
# 114 ENSP00000265016     1 311    family cdd,pfam,panther          4      +
#     chromStart chromEnd cdsStart   cdsEnd
# 114   15703065 15738313 15703145 15731845
#                                                                                    start_chr
# 114 15703145, 15705515, 15707511, 15711807, 15715285, 15715707, 15718907, 15722875, 15731740
#                                                                                      end_chr
# 114 15703332, 15705641, 15707646, 15711889, 15715361, 15715799, 15718993, 15722934, 15731821
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                       domain         enst_id
# 115      NEK1 NEK1__Protein kinase-like domain superfamily ENST00000507142
#             ensp_id start end              part_type source chromosome strand
# 115 ENSP00000424757     1 286 homologous_superfamily    ssf          4      -
#     chromStart  chromEnd  cdsStart    cdsEnd
# 115  169369704 169612632 169602630 169394510
#                                                                                             start_chr
# 115 169602514, 169602008, 169599100, 169590726, 169589447, 169588649, 169587559, 169585349, 169580852
#                                                                                               end_chr
# 115 169602630, 169602104, 169599197, 169590809, 169589514, 169588735, 169587613, 169585549, 169580902
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                      domain         enst_id         ensp_id start
# 116      NEK1 NEK1__Protein kinase domain ENST00000507142 ENSP00000424757     4
#     end part_type             source chromosome strand chromStart  chromEnd
# 116 258    domain profile,pfam,smart          4      -  169369704 169612632
#      cdsStart    cdsEnd
# 116 169602630 169394510
#                                                                                  start_chr
# 116 169602514, 169602008, 169599100, 169590726, 169589447, 169588649, 169587559, 169585382
#                                                                                    end_chr
# 116 169602621, 169602104, 169599197, 169590809, 169589514, 169588735, 169587613, 169585549
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                 domain         enst_id
# 117      NEK1 NEK1__Protein kinase, ATP binding site ENST00000507142
#             ensp_id start end    part_type  source chromosome strand chromStart
# 117 ENSP00000424757    10  33 binding_site prosite          4      -  169369704
#      chromEnd  cdsStart    cdsEnd start_chr   end_chr
# 117 169612632 169602630 169394510 169602532 169602603
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                             domain
# 118      NEK1 NEK1__Serine/threonine-protein kinase, active site
#             enst_id         ensp_id start end   part_type  source chromosome
# 118 ENST00000507142 ENSP00000424757   124 136 active_site prosite          4
#     strand chromStart  chromEnd  cdsStart    cdsEnd            start_chr
# 118      -  169369704 169612632 169602630 169394510 169590726, 169589503
#                  end_chr
# 118 169590752, 169589514
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name               domain         enst_id         ensp_id start end
# 119    FAM47E FAM47E__FAM47 family ENST00000424749 ENSP00000409423     1 392
#     part_type       source chromosome strand chromStart chromEnd cdsStart
# 119    family panther,pfam          4      +   76214040 76283783 76283458
#       cdsEnd
# 119 76251747
#                                                                          start_chr
# 119 76251747, 76256178, 76263704, 76268660, 76271568, 76278069, 76280264, 76283381
#                                                                            end_chr
# 119 76251820, 76256523, 76263843, 76268768, 76271768, 76278224, 76280341, 76283452
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name          domain         enst_id         ensp_id start end
# 120      SNCA SNCA__Synuclein ENST00000394991 ENSP00000378442     1 130
#     part_type              source chromosome strand chromStart chromEnd
# 120    family pfam,panther,prints          4      -   89700345 89838315
#     cdsStart   cdsEnd                              start_chr
# 120 89835667 89726628 89835547, 89828143, 89822246, 89729194
#                                    end_chr
# 120 89835667, 89828184, 89822388, 89729277
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                domain         enst_id         ensp_id start end
# 121      SNCA SNCA__Alpha-synuclein ENST00000394991 ENSP00000378442     1 133
#     part_type         source chromosome strand chromStart chromEnd cdsStart
# 121    family panther,prints          4      -   89700345 89838315 89835667
#       cdsEnd                                        start_chr
# 121 89726628 89835547, 89828143, 89822246, 89729194, 89726652
#                                              end_chr
# 121 89835667, 89828184, 89822388, 89729277, 89726660
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                 domain         enst_id
# 122       PAM PAM__MORF4 family-associated protein 1 ENST00000382581
#             ensp_id start end part_type       source chromosome strand
# 122 ENSP00000372024     1 127    family pfam,panther          4      +
#     chromStart chromEnd cdsStart  cdsEnd start_chr end_chr
# 122    6640091  6642729  6640863 6641246   6640863 6641243
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                      domain         enst_id
# 123    DCAF16 DCAF16__DDB1- and CUL4-associated factor 16 ENST00000382247
#             ensp_id start end part_type       source chromosome strand
# 123 ENSP00000371682     1 216    family panther,pfam          4      -
#     chromStart chromEnd cdsStart   cdsEnd start_chr  end_chr
# 123   17800655 17810758 17804141 17803491  17803494 17804141
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                                      domain
# 124    ELOVL7 ELOVL7__Elongation of very long chain fatty acids protein 7
#             enst_id         ensp_id start end part_type        source
# 124 ENST00000508821 ENSP00000424123     1 281    family hamap,panther
#     chromosome strand chromStart chromEnd cdsStart   cdsEnd
# 124          5      -   60751791 60844274 60787397 60754624
#                                                                start_chr
# 124 60787334, 60771903, 60767823, 60766574, 60764227, 60757509, 60754627
#                                                                  end_chr
# 124 60787397, 60772093, 60767903, 60766630, 60764332, 60757645, 60754833
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name             domain         enst_id         ensp_id start end
# 125    ELOVL7 ELOVL7__ELO family ENST00000508821 ENSP00000424123     2 276
#     part_type       source chromosome strand chromStart chromEnd cdsStart
# 125    family pfam,panther          5      -   60751791 60844274 60787397
#       cdsEnd
# 125 60754624
#                                                                start_chr
# 125 60787334, 60771903, 60767823, 60766574, 60764227, 60757509, 60754642
#                                                                  end_chr
# 125 60787394, 60772093, 60767903, 60766630, 60764332, 60757645, 60754833
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                             domain         enst_id
# 126    ELOVL7 ELOVL7__ELO family, conserved site ENST00000508821
#             ensp_id start end      part_type  source chromosome strand
# 126 ENSP00000424123   143 151 conserved_site prosite          5      -
#     chromStart chromEnd cdsStart   cdsEnd start_chr  end_chr
# 126   60751791 60844274 60787397 60754624  60764273 60764299
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                  domain         enst_id         ensp_id start end
# 127   C5orf24 C5orf24__DUF5568 family ENST00000394976 ENSP00000378427     1 188
#     part_type       source chromosome strand chromStart  chromEnd  cdsStart
# 127    family pfam,panther          5      +  134845680 134859735 134854901
#        cdsEnd start_chr   end_chr
# 127 134855467 134854901 134855464
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                              domain         enst_id
# 128    ZNF608 ZNF608__Zinc finger protein 608/609 ENST00000513986
#             ensp_id start  end part_type  source chromosome strand chromStart
# 128 ENSP00000421899     1 1512    family panther          5      -  124636913
#      chromEnd  cdsStart    cdsEnd
# 128 124748807 124744989 124637900
#                                                                                             start_chr
# 128 124744084, 124701014, 124649610, 124646679, 124644244, 124643511, 124641252, 124639133, 124637903
#                                                                                               end_chr
# 128 124744989, 124701269, 124649697, 124649133, 124644661, 124643683, 124641405, 124639214, 124637906
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                        domain         enst_id         ensp_id
# 129    ZNF608 ZNF608__Zinc finger C2H2-type ENST00000513986 ENSP00000421899
#     start end part_type                     source chromosome strand chromStart
# 129   555 578    domain profile,prosite,pfam,smart          5      -  124636913
#      chromEnd  cdsStart    cdsEnd start_chr   end_chr
# 129 124748807 124744989 124637900 124648650 124648721
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                             domain         enst_id
# 130      SV2C SV2C__Synaptic vesicle protein SV2 ENST00000502798
#             ensp_id start end part_type   source chromosome strand chromStart
# 130 ENSP00000423541     1 727    family tigrfams          5      +   76083383
#     chromEnd cdsStart   cdsEnd
# 130 76353939 76131751 76325547
#                                                                                                                  start_chr
# 130 76131751, 76194919, 76209736, 76285162, 76285781, 76291221, 76291768, 76295778, 76298794, 76300729, 76301386, 76325364
#                                                                                                                    end_chr
# 130 76132330, 76195099, 76209887, 76285295, 76285870, 76291331, 76291856, 76295942, 76298927, 76300932, 76301545, 76325544
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                            domain         enst_id         ensp_id
# 131      SV2C SV2C__MFS transporter superfamily ENST00000502798 ENSP00000423541
#       start     end              part_type         source chromosome strand
# 131 146,574 480,726 homologous_superfamily cathgene3d,ssf          5      +
#     chromStart chromEnd cdsStart   cdsEnd
# 131   76083383 76353939 76131751 76325547
#                                                                                                        start_chr
# 131 76132186, 76194919, 76209736, 76285162, 76285781, 76291221, 76291768, 76295778, 76300812, 76301386, 76325364
#                                                                                                          end_chr
# 131 76132330, 76195099, 76209887, 76285295, 76285870, 76291331, 76291856, 76295880, 76300932, 76301545, 76325541
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                     domain         enst_id
# 132      SV2C SV2C__Major facilitator superfamily domain ENST00000502798
#             ensp_id start end part_type  source chromosome strand chromStart
# 132 ENSP00000423541   154 722    domain profile          5      +   76083383
#     chromEnd cdsStart   cdsEnd
# 132 76353939 76131751 76325547
#                                                                                                                  start_chr
# 132 76132210, 76194919, 76209736, 76285162, 76285781, 76291221, 76291768, 76295778, 76298794, 76300729, 76301386, 76325364
#                                                                                                                    end_chr
# 132 76132330, 76195099, 76209887, 76285295, 76285870, 76291331, 76291856, 76295942, 76298927, 76300932, 76301545, 76325529
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                           domain         enst_id
# 133      SV2C SV2C__Major facilitator,  sugar transporter-like ENST00000502798
#             ensp_id start end part_type source chromosome strand chromStart
# 133 ENSP00000423541   186 369    family   pfam          5      +   76083383
#     chromEnd cdsStart   cdsEnd                                        start_chr
# 133 76353939 76131751 76325547 76132306, 76194919, 76209736, 76285162, 76285781
#                                              end_chr
# 133 76132330, 76195099, 76209887, 76285295, 76285840
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                  domain         enst_id
# 134      SV2C SV2C__Sugar transporter, conserved site ENST00000502798
#             ensp_id start end      part_type  source chromosome strand
# 134 ENSP00000423541   250 275 conserved_site prosite          5      +
#     chromStart chromEnd cdsStart   cdsEnd          start_chr            end_chr
# 134   76083383 76353939 76131751 76325547 76195086, 76209736 76195099, 76209799
# Fetching CDS for 1 proteins ... 1 found
# ...
#             source chromosome strand chromStart chromEnd cdsStart   cdsEnd
# 477 cathgene3d,ssf         18      -   42743227 43115691 43115519 42743493
#                                            start_chr
# 477 43115417, 43033811, 42974074, 42923572, 42743505
#                                              end_chr
# 477 43115474, 43033867, 42974147, 42923763, 42743720
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                 domain         enst_id
# 478      RIT2 RIT2__Small GTP-binding protein domain ENST00000326695
#             ensp_id start end part_type   source chromosome strand chromStart
# 478 ENSP00000321805    19 174    domain tigrfams         18      -   42743227
#     chromEnd cdsStart   cdsEnd                                        start_chr
# 478 43115691 43115519 42743493 43115417, 43033811, 42974074, 42923572, 42743625
#                                              end_chr
# 478 43115465, 43033867, 42974147, 42923763, 42743720
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                               domain         enst_id
# 479     ASXL3 ASXL3__Polycomb protein ASX/ASX-like ENST00000269197
#             ensp_id start  end part_type  source chromosome strand chromStart
# 479 ENSP00000269197     1 2248    family panther         18      +   33578219
#     chromEnd cdsStart   cdsEnd
# 479 33751195 33578632 33746595
#                                                                                                                  start_chr
# 479 33578632, 33607594, 33644894, 33646245, 33661616, 33670673, 33671747, 33683405, 33731968, 33734310, 33738487, 33742888
#                                                                                                                    end_chr
# 479 33578685, 33607676, 33645002, 33646353, 33661737, 33670790, 33671866, 33683568, 33732064, 33734415, 33740443, 33746592
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                    domain         enst_id         ensp_id start
# 480     ASXL3 ASXL3__ASX-like protein 3 ENST00000269197 ENSP00000269197     1
#      end part_type  source chromosome strand chromStart chromEnd cdsStart
# 480 2248    family panther         18      +   33578219 33751195 33578632
#       cdsEnd
# 480 33746595
#                                                                                                                  start_chr
# 480 33578632, 33607594, 33644894, 33646245, 33661616, 33670673, 33671747, 33683405, 33731968, 33734310, 33738487, 33742888
#                                                                                                                    end_chr
# 480 33578685, 33607676, 33645002, 33646353, 33661737, 33670790, 33671866, 33683568, 33732064, 33734415, 33740443, 33746592
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                       domain         enst_id         ensp_id
# 481     ASXL3 ASXL3__ASXL, HARE-HTH domain ENST00000269197 ENSP00000269197
#     start end part_type       source chromosome strand chromStart chromEnd
# 481    10  84    domain profile,pfam         18      +   33578219 33751195
#     cdsStart   cdsEnd                              start_chr
# 481 33578632 33746595 33578659, 33607594, 33644894, 33646245
#                                    end_chr
# 481 33578685, 33607676, 33645002, 33646250
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                    domain         enst_id         ensp_id start
# 482     ASXL3 ASXL3__ASX, DEUBAD domain ENST00000269197 ENSP00000269197   240
#     end part_type source chromosome strand chromStart chromEnd cdsStart
# 482 360    domain   pfam         18      +   33578219 33751195 33578632
#       cdsEnd                    start_chr                      end_chr
# 482 33746595 33683407, 33731968, 33734310 33683568, 33732064, 33734413
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                domain         enst_id         ensp_id start end
# 483     ASXL3 ASXL3__DEUBAD  domain ENST00000269197 ENSP00000269197   254 363
#     part_type  source chromosome strand chromStart chromEnd cdsStart   cdsEnd
# 483    domain profile         18      +   33578219 33751195 33578632 33746595
#                                  start_chr
# 483 33683449, 33731968, 33734310, 33738487
#                                    end_chr
# 483 33683568, 33732064, 33734415, 33738493
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                              domain         enst_id
# 484     ASXL3 ASXL3__Protein ASX-like, PHD domain ENST00000269197
#             ensp_id start  end part_type source chromosome strand chromStart
# 484 ENSP00000269197  2191 2246    domain   pfam         18      +   33578219
#     chromEnd cdsStart   cdsEnd start_chr  end_chr
# 484 33751195 33578632 33746595  33746419 33746586
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                           domain         enst_id
# 485    SPPL2B SPPL2B__Peptidase A22B, signal peptide peptidase ENST00000613503
#             ensp_id start end part_type       source chromosome strand
# 485 ENSP00000478298     6 565    family pfam,panther         19      +
#     chromStart chromEnd cdsStart  cdsEnd
# 485    2328615  2355095  2328710 2353209
#                                                                                                                                 start_chr
# 485 2328725, 2334602, 2337443, 2338752, 2339069, 2339824, 2340076, 2340898, 2343211, 2343965, 2344362, 2344553, 2345253, 2351434, 2352946
#                                                                                                                                   end_chr
# 485 2328775, 2334721, 2337625, 2338841, 2339208, 2339966, 2340172, 2341014, 2343292, 2344039, 2344424, 2344652, 2345330, 2351594, 2353125
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                     domain         enst_id
# 486    SPPL2B SPPL2B__Signal peptidase peptidase-like 2B ENST00000613503
#             ensp_id start end part_type  source chromosome strand chromStart
# 486 ENSP00000478298     6 565    family panther         19      +    2328615
#     chromEnd cdsStart  cdsEnd
# 486  2355095  2328710 2353209
#                                                                                                                                 start_chr
# 486 2328725, 2334602, 2337443, 2338752, 2339069, 2339824, 2340076, 2340898, 2343211, 2343965, 2344362, 2344553, 2345253, 2351434, 2352946
#                                                                                                                                   end_chr
# 486 2328775, 2334721, 2337625, 2338841, 2339208, 2339966, 2340172, 2341014, 2343292, 2344039, 2344424, 2344652, 2345330, 2351594, 2353125
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name            domain         enst_id         ensp_id start end
# 487    SPPL2B SPPL2B__PA domain ENST00000613503 ENSP00000478298    76 150
#     part_type source chromosome strand chromStart chromEnd cdsStart  cdsEnd
# 487    domain   pfam         19      +    2328615  2355095  2328710 2353209
#            start_chr          end_chr
# 487 2337482, 2338752 2337625, 2338832
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                      domain         enst_id
# 488    SPPL2B SPPL2B__Presenilin/signal peptide peptidase ENST00000613503
#             ensp_id start end part_type source chromosome strand chromStart
# 488 ENSP00000478298   217 492    family  smart         19      +    2328615
#     chromEnd cdsStart  cdsEnd
# 488  2355095  2328710 2353209
#                                                                           start_chr
# 488 2339873, 2340076, 2340898, 2343211, 2343965, 2344362, 2344553, 2345253, 2351434
#                                                                             end_chr
# 488 2339966, 2340172, 2341014, 2343292, 2344039, 2344424, 2344652, 2345330, 2351555
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                                           domain
# 489     CRLS1 CRLS1__CDP-alcohol phosphatidyltransferase, transmembrane domain
#             enst_id         ensp_id start end              part_type     source
# 489 ENST00000378863 ENSP00000368140   101 298 homologous_superfamily cathgene3d
#     chromosome strand chromStart chromEnd cdsStart  cdsEnd
# 489         20      +    6006093  6040053  6006247 6037158
#                                                         start_chr
# 489 6006547, 6009775, 6015361, 6031285, 6032012, 6034464, 6037074
#                                                           end_chr
# 489 6006552, 6009912, 6015490, 6031370, 6032080, 6034555, 6037146
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                     domain         enst_id
# 490     CRLS1 CRLS1__CDP-alcohol phosphatidyltransferase ENST00000378863
#             ensp_id start end part_type       source chromosome strand
# 490 ENSP00000368140   109 173    family prosite,pfam         20      +
#     chromStart chromEnd cdsStart  cdsEnd        start_chr          end_chr
# 490    6006093  6040053  6006247 6037158 6009793, 6015361 6009912, 6015435
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                  domain         enst_id
# 491    DDRGK1 DDRGK1__DDRGK domain containing protein ENST00000354488
#             ensp_id start end part_type     source chromosome strand chromStart
# 491 ENSP00000346483   115 303    family smart,pfam         20      -    3190350
#     chromEnd cdsStart  cdsEnd
# 491  3204685  3204627 3190653
#                                                         start_chr
# 491 3200342, 3200001, 3195231, 3194830, 3191765, 3191190, 3190689
#                                                           end_chr
# 491 3200407, 3200102, 3195353, 3194868, 3191821, 3191238, 3190819
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                              domain
# 492    DDRGK1 DDRGK1__Winged helix DNA-binding domain superfamily
#             enst_id         ensp_id start end              part_type source
# 492 ENST00000354488 ENSP00000346483   209 279 homologous_superfamily    ssf
#     chromosome strand chromStart chromEnd cdsStart  cdsEnd
# 492         20      -    3190350  3204685  3204627 3190653
#                                       start_chr
# 492 3195231, 3194830, 3191765, 3191190, 3190761
#                                         end_chr
# 492 3195239, 3194868, 3191821, 3191238, 3190819
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                                   domain
# 493    DDRGK1 DDRGK1__Winged helix-like DNA-binding domain superfamily
#             enst_id         ensp_id start end              part_type     source
# 493 ENST00000354488 ENSP00000346483   214 271 homologous_superfamily cathgene3d
#     chromosome strand chromStart chromEnd cdsStart  cdsEnd
# 493         20      -    3190350  3204685  3204627 3190653
#                              start_chr                            end_chr
# 493 3194830, 3191765, 3191190, 3190785 3194862, 3191821, 3191238, 3190819
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name
# 494    DYRK1A
#                                                                      domain
# 494 DYRK1A__Dual specificity tyrosine-phosphorylation-regulated kinase 1A/B
#             enst_id         ensp_id start end part_type  source chromosome
# 494 ENST00000647188 ENSP00000494572    20 709    family panther         21
#     strand chromStart chromEnd cdsStart   cdsEnd
# 494      +   37365573 37526358 37420375 37512531
#                                                                                              start_chr
# 494 37472731, 37478208, 37480638, 37486467, 37490175, 37493017, 37496118, 37505283, 37506099, 37511911
#                                                                                                end_chr
# 494 37472880, 37478300, 37480826, 37486614, 37490461, 37493163, 37496258, 37505589, 37506223, 37512393
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                         domain         enst_id
# 495    DYRK1A DYRK1A__Protein kinase-like domain superfamily ENST00000647188
#             ensp_id start end              part_type source chromosome strand
# 495 ENSP00000494572   147 489 homologous_superfamily    ssf         21      +
#     chromStart chromEnd cdsStart   cdsEnd
# 495   37365573 37526358 37420375 37512531
#                                                      start_chr
# 495 37480776, 37486467, 37490175, 37493017, 37496118, 37505283
#                                                        end_chr
# 495 37480826, 37486614, 37490461, 37493163, 37496258, 37505537
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name
# 496    DYRK1A
#                                                                                         domain
# 496 DYRK1A__Dual specificity tyrosine-phosphorylation-regulated kinase 1A/1B, catalytic domain
#             enst_id         ensp_id start end part_type source chromosome
# 496 ENST00000647188 ENSP00000494572   148 484    domain    cdd         21
#     strand chromStart chromEnd cdsStart   cdsEnd
# 496      +   37365573 37526358 37420375 37512531
#                                                      start_chr
# 496 37480779, 37486467, 37490175, 37493017, 37496118, 37505283
#                                                        end_chr
# 496 37480826, 37486614, 37490461, 37493163, 37496258, 37505522
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                        domain         enst_id         ensp_id
# 497    DYRK1A DYRK1A__Protein kinase domain ENST00000647188 ENSP00000494572
#     start end part_type             source chromosome strand chromStart
# 497   159 479    domain profile,pfam,smart         21      +   37365573
#     chromEnd cdsStart   cdsEnd
# 497 37526358 37420375 37512531
#                                                      start_chr
# 497 37480812, 37486467, 37490175, 37493017, 37496118, 37505283
#                                                        end_chr
# 497 37480826, 37486614, 37490461, 37493163, 37496258, 37505507
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                   domain         enst_id
# 498    DYRK1A DYRK1A__Protein kinase, ATP binding site ENST00000647188
#             ensp_id start end    part_type  source chromosome strand chromStart
# 498 ENSP00000494572   165 188 binding_site prosite         21      +   37365573
#     chromEnd cdsStart   cdsEnd start_chr  end_chr
# 498 37526358 37420375 37512531  37486470 37486541
# Fetching CDS for 1 proteins ... 1 found
# Checking CDS and protein sequence lengths ... 1/1 OK
#     gene_name                                               domain
# 499    DYRK1A DYRK1A__Serine/threonine-protein kinase, active site
#             enst_id         ensp_id start end   part_type  source chromosome
# 499 ENST00000647188 ENSP00000494572   283 295 active_site prosite         21
#     strand chromStart chromEnd cdsStart   cdsEnd start_chr  end_chr
# 499      +   37365573 37526358 37420375 37512531  37490384 37490422
# There were 21 warnings (use warnings() to see them)

# %%
new_df.to_csv('domains.txt', sep = '\t', index=False)

# %%
# !pip show pandas
# Out:
# Name: pandas
# Version: 1.3.5
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: pytz, numpy, python-dateutil
# Required-by: xarray, vega-datasets, statsmodels, sklearn-pandas, seaborn, pymc3, plotnine, pandas-profiling, pandas-gbq, pandas-datareader, mlxtend, mizani, holoviews, gspread-dataframe, google-colab, fix-yahoo-finance, fbprophet, fastai, cufflinks, cmdstanpy, bioservices, arviz, altair
